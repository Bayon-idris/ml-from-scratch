# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, log_loss
from tqdm import tqdm

# %%
import sys, os
sys.path.append(os.path.abspath(".."))
from utilities.utilities import *

# %%
def initialisation(dimensions):
    
    parameters = {}
    C = len(dimensions)
    np.random.seed(1)
    for c in range(1, C):
        parameters['W' + str(c)] = np.random.randn(dimensions[c], dimensions[c - 1])
        parameters['b' + str(c)] = np.random.randn(dimensions[c], 1)

    return parameters

# %%
def preprocess(X):
    X = X.reshape(X.shape[0], -1)
    X = X/255.0
    return X

# %%
def forward_propagation(X, parameters):
  
    activations = {'A0': X}
    # le nombre de parametre wi,bi definit le nombre de couches lorsqu'on divise par 2
    C = len(parameters) // 2
    for c in range(1, C + 1):
        Z = parameters['W' + str(c)].dot(activations['A' + str(c - 1)]) + parameters['b' + str(c)]
        activations['A' + str(c)] = 1 / (1 + np.exp(-Z))

    return activations

# %%
def back_propagation(y, parameters, activations):

  m = y.shape[1]
  C = len(parameters) // 2
  dZ = activations['A' + str(C)] - y
  gradients = {}

  for c in reversed(range(1, C + 1)):
    gradients['dW' + str(c)] = 1/m * np.dot(dZ, activations['A' + str(c - 1)].T)
    gradients['db' + str(c)] = 1/m * np.sum(dZ, axis=1, keepdims=True)
    if c > 1:
      dZ = np.dot(parameters['W' + str(c)].T, dZ) * activations['A' + str(c - 1)] * (1 - activations['A' + str(c - 1)])

  return gradients

# %%
def update(gradients, parameters, learning_rate):

    C = len(parameters) // 2

    for c in range(1, C + 1):
        parameters['W' + str(c)] = parameters['W' + str(c)] - learning_rate * gradients['dW' + str(c)]
        parameters['b' + str(c)] = parameters['b' + str(c)] - learning_rate * gradients['db' + str(c)]

    return parameters

# %%
def predict(X, parameters):
  activations = forward_propagation(X, parameters)
  C = len(parameters) // 2
  Af = activations['A' + str(C)]
  return Af >= 0.5

# %%
X_train, y_train, X_test, y_test = load_data()
X_train = preprocess(X_train).T           
X_test = preprocess(X_test).T

# %%
def deep_neural_network(X_train, y_train, X_test, y_test, hidden_layers=(16, 16, 16), learning_rate=0.001, n_iter=3000):

    y_train = y_train.reshape(1, -1)
    y_test = y_test.reshape(1, -1)

    # initialisation des dimensions
    dimensions = list(hidden_layers)
    dimensions.insert(0, X_train.shape[0])   # entrée
    dimensions.append(y_train.shape[0])      # sortie

    np.random.seed(1)
    parameters = initialisation(dimensions)

    # historique train et test : loss + acc
    training_history = np.zeros((int(n_iter), 4))  
    # colonnes : train_loss, train_acc, test_loss, test_acc

    C = len(parameters) // 2

    for i in tqdm(range(n_iter)):

        # forward + backward sur train
        activations = forward_propagation(X_train, parameters)
        gradients = back_propagation(y_train, parameters, activations)
        parameters = update(gradients, parameters, learning_rate)
        Af_train = activations['A' + str(C)]

        # calcul train loss + acc
        training_history[i, 0] = log_loss(y_train.flatten(), Af_train.flatten())
        y_pred_train = predict(X_train, parameters)
        training_history[i, 1] = accuracy_score(y_train.flatten(), y_pred_train.flatten())

        # calcul test loss + acc
        activations_test = forward_propagation(X_test, parameters)
        Af_test = activations_test['A' + str(C)]
        training_history[i, 2] = log_loss(y_test.flatten(), Af_test.flatten())
        y_pred_test = predict(X_test, parameters)
        training_history[i, 3] = accuracy_score(y_test.flatten(), y_pred_test.flatten())

    # Plot courbes d'apprentissage
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(training_history[:, 0], label='train loss')
    plt.plot(training_history[:, 2], label='test loss')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(training_history[:, 1], label='train acc')
    plt.plot(training_history[:, 3], label='test acc')
    plt.legend()
    plt.show()

    return training_history, parameters

# %%
training_history, parametres = deep_neural_network(X_train, y_train, X_test, y_test, hidden_layers = (16, 16, 16), learning_rate = 0.1, n_iter = 100)
print("Shape de X_test :", X_test.shape)
print("Shape de y_test :", y_test.shape)
y_pred = predict(X_test, parameters)
print("Shape de y_pred :", y_pred.shape)
print("Test Accuracy :", accuracy_score(y_test, y_pred))
# Out:
#   0%|                                                                                          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 training_history, parametres = deep_neural_network(X_train, y_train, X_test, y_test, hidden_layers = (16, 16, 16), learning_rate = 0.1, n_iter = 100)
#       2 y_pred = predict(X_test, parameters)
#       3 print("Shape de y_pred :", y_pred.shape)
#       4 print("Test Accuracy :", accuracy_score(y_test, y_pred))
#
# Cell In[67], line 34, in deep_neural_network(X_train, y_train, X_test, y_test, hidden_layers, learning_rate, n_iter)
#      30         y_pred_train = predict(X_train, parameters)
#      31         training_history[i, 1] = accuracy_score(y_train.flatten(), y_pred_train.flatten())
#      32
#      33         # calcul test loss + acc
# ---> 34         activations_test = forward_propagation(X_test, parameters)
#      35         Af_test = activations_test['A' + str(C)]
#      36         training_history[i, 2] = log_loss(y_test.flatten(), Af_test.flatten())
#      37         y_pred_test = predict(X_test, parameters)
#
# Cell In[21], line 7, in forward_propagation(X, parametres)
#       3     activations = {'A0': X}
#       4     # le nombre de parametre wi,bi definit le nombre de couches lorsqu'on divise par 2
#       5     C = len(parametres) // 2
#       6     for c in range(1, C + 1):
# ----> 7         Z = parametres['W' + str(c)].dot(activations['A' + str(c - 1)]) + parametres['b' + str(c)]
#       8         activations['A' + str(c)] = 1 / (1 + np.exp(-Z))
#       9
#      10     return activations
#
# ValueError: shapes (16,4096) and (200,4096) not aligned: 4096 (dim 1) != 200 (dim 0)
